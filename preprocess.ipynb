# %%
#read the csv file and print the data from 91APP_Dataset dictionary
import csv
import json
import sys
import os
import pandas as pd

data = pd.read_csv('Datasets\\91APP_Dataset(session02)\\session02_202402.csv')
# Out:
# C:\Users\d3m2w\AppData\Local\Temp\ipykernel_22036\1873956949.py:8: DtypeWarning: Columns (14,15,20,21,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Datasets\91APP_Dataset(session02)\session02_202402.csv')

# %%
#create a subdata which contains 2000 rows
subdata = data.head(2000)
#save the subdata to a new csv file
subdata.to_csv('Datasets\\91APP_Dataset(session02)\\subdata.csv',index=False)
